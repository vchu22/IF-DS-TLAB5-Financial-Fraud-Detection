# %% [markdown]
# # EDA
#
# Create your own EDA below/ Create as many code-blocks as you need.
#
# Once you've completed your EDA, complete the section titled **Reflections** where you will answer questions about your EDA.
#
# **Note**: Since this dataset is large, visualizations might load slower. You may want to consider using the `sample()` method if this dataset is too large for your computer to process in a reasonable amount of time.

# %%
import pandas as pd 
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt

# %%
# import data 
transactions = pd.read_csv("../data/bank_transactions.csv")

transactions.head()
# Out:
#        type      amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0   PAYMENT      983.09  C1454812978       36730.24        35747.15
# 1   PAYMENT    55215.25  C1031766358       99414.00        44198.75
# 2   CASH_IN   220986.01  C1451868666     7773074.97      7994060.98
# 3  TRANSFER  2357394.75   C458368123           0.00            0.00
# 4  CASH_OUT    67990.14  C1098978063           0.00            0.00
#
#       nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud
# 0  M1491308340            0.00            0.00        0               0
# 1  M2102868029            0.00            0.00        0               0
# 2  C1339195526       924031.48       703045.48        0               0
# 3   C620979654      4202580.45      6559975.19        0               0
# 4   C142246322       625317.04       693307.19        0               0

# %%
# TODO: view the shape of your data
transactions.shape
# Out:
# (1000000, 10)

# %%
# TODO: Begin your EDA

# For Q1
plt.title("Distribution of amounts")
plt.xlim(left=0, right=2000000)
plt.xticks(range(0,2000000, 400000))
transactions["amount"].plot.hist(bins=2000)
# Out:
# <Axes: title={'center': 'Distribution of amounts'}, ylabel='Frequency'>

# %%
plt.title("Distribution of oldbalanceOrg")
plt.xlim(left=0, right=500000)
plt.xticks(range(0,500000, 100000))
transactions["oldbalanceOrg"].plot.hist(bins=2500)
# Out:
# <Axes: title={'center': 'Distribution of oldbalanceOrg'}, ylabel='Frequency'>

# %%
plt.title("Distribution of newbalanceOrig")
plt.xlim(left=0, right=250000)
plt.xticks(range(0,250000, 50000))
transactions["newbalanceOrig"].plot.hist(bins=2500)
# Out:
# <Axes: title={'center': 'Distribution of newbalanceOrig'}, ylabel='Frequency'>

# %%
plt.title("Distribution of oldbalanceDest")
plt.xlim(left=0, right=1000000)
plt.xticks(range(0,1000000, 200000))
transactions["oldbalanceDest"].plot.hist(bins=4000)
# Out:
# <Axes: title={'center': 'Distribution of oldbalanceDest'}, ylabel='Frequency'>

# %%
plt.title("Distribution of newbalanceDest")
plt.xlim(left=0, right=1000000)
plt.xticks(range(0,1000000, 200000))
transactions["newbalanceDest"].plot.hist(bins=4000)
# Out:
# <Axes: title={'center': 'Distribution of newbalanceDest'}, ylabel='Frequency'>

# %% [markdown]
# # EDA for Q2

# %%
# For Q2
fraudulent_transactions = transactions[transactions['isFraud'] == 1]
fraudulent_transactions.describe()
# Out:
#              amount  oldbalanceOrg  newbalanceOrig  oldbalanceDest  \
# count  1.297000e+03   1.297000e+03    1.297000e+03    1.297000e+03
# mean   1.355199e+06   1.509793e+06    1.561442e+05    4.525605e+05
# std    2.252516e+06   3.239191e+06    1.649550e+06    1.853027e+06
# min    0.000000e+00   0.000000e+00    0.000000e+00    0.000000e+00
# 25%    1.204119e+05   1.193061e+05    0.000000e+00    0.000000e+00
# 50%    4.073478e+05   4.041651e+05    0.000000e+00    0.000000e+00
# 75%    1.425063e+06   1.425063e+06    0.000000e+00    1.285299e+05
# max    1.000000e+07   3.958504e+07    2.958504e+07    4.614176e+07
#
#        newbalanceDest  isFraud  isFlaggedFraud
# count    1.297000e+03   1297.0     1297.000000
# mean     1.132291e+06      1.0        0.000771
# std      2.612255e+06      0.0        0.027767
# min      0.000000e+00      1.0        0.000000
# 25%      0.000000e+00      1.0        0.000000
# 50%      7.304560e+03      1.0        0.000000
# ...

# %%
normal = transactions[transactions['isFraud'] == 0]
normal.describe()
# Out:
#              amount  oldbalanceOrg  newbalanceOrig  oldbalanceDest  \
# count  9.987030e+05   9.987030e+05    9.987030e+05    9.987030e+05
# mean   1.780941e+05   8.342422e+05    8.574200e+05    1.103700e+06
# std    6.010807e+05   2.892341e+06    2.930086e+06    3.466442e+06
# min    3.000000e-02   0.000000e+00    0.000000e+00    0.000000e+00
# 25%    1.334550e+04   0.000000e+00    0.000000e+00    0.000000e+00
# 50%    7.426004e+04   1.396900e+04    0.000000e+00    1.338230e+05
# 75%    2.079743e+05   1.070470e+05    1.451714e+05    9.440707e+05
# max    9.244552e+07   3.856340e+07    3.893942e+07    3.555534e+08
#
#        newbalanceDest   isFraud  isFlaggedFraud
# count    9.987030e+05  998703.0        998703.0
# mean     1.227983e+06       0.0             0.0
# std      3.753943e+06       0.0             0.0
# min      0.000000e+00       0.0             0.0
# 25%      0.000000e+00       0.0             0.0
# 50%      2.150631e+05       0.0             0.0
# ...

# %%
sns.scatterplot(data=transactions, x="amount", y="newbalanceOrig", hue="isFraud")
# Out:
# <Axes: xlabel='amount', ylabel='newbalanceOrig'>

# %%
sns.scatterplot(data=transactions, x="oldbalanceOrg", y="oldbalanceDest", hue="isFraud")
# Out:
# <Axes: xlabel='oldbalanceOrg', ylabel='oldbalanceDest'>

# %% [markdown]
# ## EDA for Q5

# %%
# For Q5
fraudulent_transactions.shape
# Out:
# (1297, 10)

# %%
fraud_flagged = transactions[transactions['isFlaggedFraud'] == 1]
fraud_flagged.shape
# Out:
# (1, 10)

# %%
pd.pivot_table(transactions, values='isFraud', index='isFlaggedFraud', aggfunc='sum')
# Out:
#                 isFraud
# isFlaggedFraud
# 0                  1296
# 1                     1

# %% [markdown]
# ## Reflections
#
# Answer each question based on the visualizations that you've generated.
#
# Remember, you must justify your answers with proof.

# %% [markdown]
# ### Q1
#
# Take a closer look at the numeric features in your dataset. How are these values distributed and what might this tell you about how most transactions behave compared to a few **rare** ones?
#
# **Hint**: Consider using visualizations that highlight frequency across value ranges.
#
# - Based on the visualizations for the frequencies of each numeric features's values which are split into bins, we can see that the majority of the values fall into the categories closest to 0 and the transactions with large amounts are rate.

# %% [markdown]
# ### Q2
#
# When comparing different numerical features against one another, do any interesting patterns emerge for transactions marked as fraudulent? Are there particular regions or ranges where these transactions seem to concentrate?
#
# **Hint**: Try comparing two numeric features at a time while distinguishing between fraud and non-fraud. Use visual cues to spot clusters or anomalies.
#
# - Based on the scatter plot comparing between `amount` and `newbalanceOrig` with data points differentiated by the isFraud flag, most of the fraudulent transactions have `amount` value around 10,000,000. For comparison between `oldbalanceOrg` and `oldbalanceDest`, we found most fraudulent transactions `oldbalanceDest` around 0.

# %% [markdown]
# ### Q3
#
# How do types of transaction relate to the typical amounts involved? Are some types of transactions consistently larger or smaller than others?
#
# **Hint**: Break the dataset down by transaction type and compare summary statistics.

# %% [markdown]
# ### Q4
#
# Do transaction amounts vary when you compare fraudulent and non-fraudulent transactions across different transaction types? What patterns emerge when you look at both fraud status and transaction type together?
#
# **Hint**:  Try summarizing average transaction amounts by both fraud label and transaction type to compare across categories.
#
# Answer here

# %% [markdown]
# ## Q5
#
# Consider how well the system's built-in fraud flag (`isFlaggedFraud`) aligns with actual fraudulent activity. Are there mismatches? What does this tell you about the system's current performance?
#
# **Hint**: Try organizing the data in a way that shows how often flagged transactions are truly fraudulent and how often fraud goes unflagged.
#
# - The number is rows with the value of 1 for isFraud is 1297 while there is only 1 row with isFlaggedFraud value of 1. The pivot table also shows that the number of rows with both `isFraud` and `isFlaggedFraud` equals to `1`. Therefore, we can conclude that the system does not perform well because most actual fraudulent transactions were not flagged by the system.
